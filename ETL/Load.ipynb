# %%
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus

df = pd.read_csv(r'C:\Users\indur\OneDrive\Desktop\power bi projects\Public_Transport_Delay\public_transport_delay_cleaned.csv')
df
# Out:
#        Unnamed: 0  TRIP_ID       CITY     ROUTE_ID  HOUR DAY_OF_WEEK  \
# 0               0      TR1  Hyderabad      Busss88     4    Saturday
# 1               1      TR2      Delhi      Busss55    20    Saturday
# 2               2      TR3    Chennai  Local_Train    10    Saturday
# 3               3      TR4  Hyderabad  Local_Train     3      Friday
# 4               4      TR5    Chennai      Busss55     3      Sunday
# ...           ...      ...        ...          ...   ...         ...
# 44995       44995  TR44996      Delhi     Metrored    14      Sunday
# 44996       44996  TR44997    Chennai      Busss88     2      Monday
# 44997       44997  TR44998     Mumbai     Metrored    12   Wednesday
# 44998       44998  TR44999      Delhi      Busss88    15    Saturday
# 44999       44999  TR45000  Bangalore     Metrored    21    Saturday
#
#       RAINFALL_MM  TEMPERATURE  HUMIDITY WIND_SPEED RUSH_HOUR   TRAFFIC_LEVEL  \
# ...

# %%
try:

    
    user = 'root'
    password = quote_plus('induri@05')
    host = 'localhost'
    database = 'transport'

    engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}/{database}')

    df.to_sql('transport',con=engine,if_exists='replace',index=False)

except Exception as e:
    print('e')

finally:
    print('successfully we loaded data into MYSQL WORKBENCH')
    print('successfully we ETL process is DONE....................')
# Out:
# successfully we loaded data into MYSQL WORKBENCH
# successfully we ETL process is DONE....................
